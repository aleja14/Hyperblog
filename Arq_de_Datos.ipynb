# %% [markdown]
# <a href="https://colab.research.google.com/github/aleja14/Hyperblog/blob/master/Arq_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install diagrams

# %% [markdown]
# #Imports

# %%
from diagrams import Diagram, Edge, Cluster
from diagrams.aws.database import RDS
from diagrams.aws.business import BusinessApplications
from diagrams.onprem.client import User
from diagrams.aws.business import AlexaForBusiness
from diagrams.aws.enduser import DesktopAndAppStreaming
from diagrams.aws.enduser import Appstream20
from diagrams.aws.general import Multimedia
from diagrams.aws.general import MobileClient
from diagrams.aws.general import TraditionalServer
from diagrams.aws.analytics import Kinesis
from diagrams.aws.storage import SimpleStorageServiceS3
from diagrams.aws.analytics import GlueCrawlers
from diagrams.aws.analytics import Glue
from diagrams.aws.integration import StepFunctions
from diagrams.aws.analytics import Athena
from diagrams.aws.database import Neptune
from diagrams.aws.database import Dynamodb
from diagrams.aws.security import IdentityAndAccessManagementIamRole
from diagrams.aws.security import  IAMPermissions
from diagrams.aws.analytics import GlueDataCatalog
from diagrams.aws.enduser import Workdocs
from diagrams.aws.analytics import Redshift
from diagrams.aws.analytics import Quicksight
from diagrams.aws.management import Cloudformation
from diagrams.aws.network import VPC
from diagrams.aws.security import IAM
from diagrams.aws.analytics import LakeFormation
from diagrams.aws.security import KMS
from diagrams.aws.management import Cloudtrail
from diagrams.aws.management import Cloudwatch
from diagrams.aws.database import DB
from diagrams.aws.ml import Sagemaker
from diagrams.aws.analytics import ES
from diagrams.aws.ml import Transcribe
from urllib.request import urlretrieve
from diagrams.custom import Custom
from diagrams.aws.analytics  import Analytics

# %% [markdown]
# # País 1 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad1 País1", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama
# Out:
# ...
#  Arquitectura Data Mesh Unidad1 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad1 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad1 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad1 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad1 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad1 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad1 País1' size too small for label

# %% [markdown]
# #País 1 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País1", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1
# Out:
# ...
#  Arquitectura Data Mesh Unidad 2 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 2 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 2 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 2 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 2 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 2 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 2 País1' size too small for label

# %% [markdown]
# #País 1 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País1", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1
# Out:
# ...
#  Arquitectura Data Mesh Unidad 3 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 3 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 3 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 3 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 3 País1' size too small for label

# %% [markdown]
# #País 1 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País1", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1
# Out:
# ...
#  Arquitectura Data Mesh Unidad 4 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 4 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 4 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 4 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 4 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 4 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 4 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 4 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 4 País1' size too small for label
# ...
#  Arquitectura Data Mesh Unidad 4 País1' size too small for label

# %% [markdown]
# # País 2 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País2", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 2 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País2", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 2 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País2", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 2 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País2", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 3 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País3", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 3 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País3", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 3 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País3", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 3 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País3", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 4 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País4", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 4 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País4", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 4 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País4", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 4 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País4", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 5 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País5", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 5 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País5", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 5 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País5"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 5 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País5"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 6 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País6", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 6 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País6", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 6 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País6"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 6 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País6"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 7 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País7", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 7 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País7", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 7 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País7"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 7 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País7", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 8 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País8, show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 8 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País8", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 8 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País8"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 8 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País8", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 9 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País9", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 9 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País9", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 9 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País9"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 9 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País9", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 10 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País10", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 10 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País10", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 10 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País10"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 10 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País10", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 11 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País11", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 11 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País11", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 11 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País11"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 11 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País11", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 12 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País12" show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 12 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País12", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 12 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País12"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 12 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País12", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 13 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País13", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 13 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País13", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 13 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País13", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 13 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País13"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 14 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País14", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 14 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País14", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 14 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País14"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 14 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País14", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 15 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País15", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 15 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País15", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 15 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 Pas15"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 15 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País5", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 16 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País16", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 16 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País16", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 16 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País16"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 16 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País16", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 17 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País17", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 17 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País17", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 17 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País17"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 17 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País17", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 18 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País18", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 18 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País18", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 18 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País18"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 18 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País18", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 19 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País19", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 19 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País19", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 19 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País19"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 19 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País19", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 20 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País20", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 20 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País20", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 20 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País20"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 20 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País20", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 21 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País21", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 21 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País21", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 21 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País21"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 21 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País21", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 22 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País22", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 22 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País22", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 22- Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País22"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 22 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País22", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 23 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País23", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 23 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País23", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 23 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País23"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 23 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País23", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 24 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País24", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 24 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País24", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 24 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País24"	, show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 24 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País24", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# # País 25 - Unidad de negocio 1

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 1 País25", show = False) as miDiagrama:
    App = MobileClient("App")
    web = TraditionalServer("streaming Data")

    with Cluster("Aws Cloud Unidad de Negocio 1"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
        group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
miDiagrama

# %% [markdown]
# #País 25 - Unidad de negocio 2

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 2 País25", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")

    with Cluster("Aws Cloud Unidad de Negocio 2"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 25 - Unidad de negocio 3

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 3 País25", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")

    with Cluster("Aws Cloud Unidad de Negocio 3"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")     
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
    

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")

miDiagrama1

# %% [markdown]
# #País 25 - Unidad de negocio 4

# %%
with Diagram("\n Arquitectura Data Mesh Unidad 4 País25", show = False) as miDiagrama1:
    web = TraditionalServer("Reporte de Denuncias")
    bd = DB ("Databases")
  
    with Cluster("Aws Cloud Unidad de Negocio 4"):
      with Cluster("Ingestión"):
        db_primary = Kinesis("Kinesis")
      with Cluster("Productor-Dominio2"):
        productor= SimpleStorageServiceS3("Bucket")
        step = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue0 = GlueCrawlers("Crawlers") 
              Glue1 = Glue ("Glue")
              Glue2 = Glue ("Glue")
        s3 = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue3 = GlueCrawlers("Crawlers")
              Glue4 = Glue ("Glue")
              Glue5 = Glue ("Glue")
        s = SimpleStorageServiceS3 ("Bucket")
      with Cluster ("Lake Formation- Plataforma Central"):
        bucket15 = SimpleStorageServiceS3 ("Bucket")
        with Cluster ("Metadata"):
          group = [Neptune("Amazon Neptune"),
                  Dynamodb("Amazon DynamoDB"),
                  Glue("AWS Glue")] 
        with Cluster ("Gobernanza"):
          group1 = [IdentityAndAccessManagementIamRole("Role"),
                  IAMPermissions("permissions")]
        with Cluster ("Discovery"):
          group1 = [GlueDataCatalog("Glue DataBrew"),
                  Workdocs("BluePrint"),
                  Transcribe("ML Tranformation")] 
      with Cluster("Productor-Dominio1"):
        productor2= SimpleStorageServiceS3("Bucket")
        step1 = [StepFunctions ("StepFunction")]
        with Cluster("Validación, limpieza"):
          with Cluster("Glue WorkFlow"):
              Glue7 = GlueCrawlers("Crawlers")
              Glue8 = Glue ("Glue")
              Glue9 = Glue ("Glue")
        bucket = SimpleStorageServiceS3 ("Bucket")
        with Cluster("Normalización y Transformación"):
          with Cluster("Glue WorkFlow"):
              Glue10 = GlueCrawlers("Crawlers")
              Glue11 = Glue ("Glue")
              Glue12 = Glue ("Glue")
        bucket1 = SimpleStorageServiceS3 ("Bucket")           
      with Cluster ("Consumidor Dominio 2"):
          Bucket4 = SimpleStorageServiceS3("Bucket")
          Red =     Redshift("Redshift")
          Quick =   Quicksight("Amazon QuickSigh")
          Cloud =   Cloudformation ("AWS CloudFormation")
          Ath= Analytics ("Amazon Athena")
      with Cluster ("Consumidor Dominio 1"):
          Bucket5 = SimpleStorageServiceS3("Bucket")
          Red1 =     Redshift("Redshift")
          Quick1 =   Quicksight("Amazon QuickSigh")
          Cloud1 =   Cloudformation ("AWS CloudFormation")
          Ath1= Analytics ("Amazon Athena")
      with Cluster ("Seguridad y Monitoreo"):
       group10 = [VPC("VPC"),
                   IAM ("IAM"), 
                   LakeFormation("LAKEFORMATION"), 
                   KMS("KMS"), 
                   Cloudtrail("CLOUDTRAIL"), 
                   Cloudwatch("CLOUDWATCH")]
      with Cluster ("ML y Analítica"):
          Group16 = [Analytics ("Amazon Athena"),
                     Sagemaker("Amazon SageMaker"),
                     ES("ElasticsearchService")]

    App >> web >> db_primary >> productor >> Glue0
    bd >> db_primary
    step >> Glue0
    step >> Glue3
    Glue0 >> Glue1
    Glue0 >> Glue2
    Glue1 >> s3
    Glue2 >> s3
    Glue3 >> Glue4
    Glue3 >> Glue5
    s3 >> Glue3
    Glue4 >> s
    Glue5 >> s
    s \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    db_primary >> productor2 >> Glue7
    step1 >> Glue7
    step1 >> Glue10
    Glue7 >> Glue8
    Glue7 >> Glue9
    Glue8 >> bucket
    Glue9 >> bucket
    Glue10 >> Glue11
    Glue10 >> Glue12
    bucket >> Glue10
    Glue11 >> bucket1
    Glue12 >> bucket1
    bucket1 \
        >> Edge(color="Black") \
        << group \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket4 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Bucket5 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Red1 \
        >> Edge(color="Black") 
    group \
        >> Edge(color="Black") \
        << Quick1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Cloud1 \
        >> Edge(color="Black")
    group \
        >> Edge(color="Black") \
        << Ath1 \
        >> Edge(color="Black")
    Group16 \
        >> Edge(color="Black") \
        << bucket15 \
        >> Edge(color="Black")

miDiagrama1
